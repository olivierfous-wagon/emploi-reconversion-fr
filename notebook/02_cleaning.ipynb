# %% [markdown]
# 1. Objectif du nettoyage

# %% [markdown]
# L'objectif de cette étape est des transformer les données brutes en données exploitables pour l'analyse, sans en modifier le sens ou la granularité.
#
# Le nettoyage vise à :
# - standardiser les noms de colonnes pour faciliter leur manipulation en Python/SQL
# - identifier et formater la dimension temporelle
# - filtrer un périmètre cohérent (géographique et périodique)
# - sélectionner les variables utiles pour l'analyse
# - préparer une table propre et stable pour les étapes suivantes

# %% [markdown]
# 2. Chargement des données

# %%
import pandas as pd
df_raw_dares = pd.read_csv("../data/raw/france_travail/dares_defm_stock_france_brut_trim.csv", sep =";")

# %%
df_raw_dares.head()
# Out:
#       Date                  Champ Type de données Catégorie    Sexe  \
# 0  1996-T1  France métropolitaine          Brutes         C   Total
# 1  1996-T1  France métropolitaine          Brutes         C  Hommes
# 2  1996-T1  France métropolitaine          Brutes         D   Total
# 3  1996-T1  France métropolitaine          Brutes         E   Total
# 4  1996-T1  France métropolitaine          Brutes         A  Hommes
#
#      Tranche d'âge Tranche d'heures travaillées Ancienneté Formation  \
# 0            Total                        Total      Total     Total
# 1            Total                        Total      Total     Total
# 2            Total                        Total      Total     Total
# 3            Total                        Total      Total     Total
# 4  Moins de 25 ans                        Total      Total     Total
#
#   Formation (ancienne mesure) Métier recherché Indemnisabilité Qualification  \
# 0                       Total            Total           Total         Total
# 1                       Total            Total           Total         Total
# 2                       Total            Total           Total         Total
# 3                       Total            Total           Total         Total
# 4                       Total            Total           Total         Total
#
#    Nombre de demandeurs d'emploi
# 0                         324100
# 1                         148800
# 2                         181500
# 3                         202200
# 4                         315600

# %%
df_dares = df_raw_dares.copy()

# %%
df_raw_insee20 = pd.read_csv("../data/raw/insee/FD_csv_EEC20.csv", sep=";")
df_raw_insee21 = pd.read_csv("../data/raw/insee/FD_EEC_2021.csv", sep=";")
df_raw_insee22 = pd.read_csv("../data/raw/insee/FD_EEC_2022.csv", sep=";")
df_raw_insee23 = pd.read_csv("../data/raw/insee/FD_csv_EEC23.csv", sep=";")

# %%
df_raw_insee = pd.concat([df_raw_insee20, df_raw_insee21, df_raw_insee22, df_raw_insee23])

# %%
df_insee = df_raw_insee.copy()

# %%
df_insee.columns
# Out:
# Index(['ANNEE', 'TRIM', 'CATAU2010R', 'METRODOM', 'TYPMEN7', 'AGE3', 'AGE5',
#        'COURED', 'ENFRED', 'NFRRED',
#        ...
#        'APCS2', 'CHAMP_M_15_89', 'ESEG_1', 'ESEG_2', 'NATIO', 'PCSL', 'PCSP',
#        'SO', 'STAT_CS', 'STAT_CSPRL'],
#       dtype='object', length=177)

# %%
df_insee["periode"] = (
    pd.PeriodIndex.from_fields(
        year=df_insee["ANNEE"].astype(int),
        quarter=df_insee["TRIM"].astype(int),
        freq="Q"
    )
    .to_timestamp(how="start")
)

# %%
df_insee[["ANNEE", "TRIM", "periode"]].head()
# Out:
#    ANNEE  TRIM    periode
# 0   2020     4 2020-10-01
# 1   2020     1 2020-01-01
# 2   2020     1 2020-01-01
# 3   2020     2 2020-04-01
# 4   2020     2 2020-04-01

# %%
df_insee = df_insee[(df_insee["ANNEE"] >= 2020) & (df_insee["ANNEE"] <= 2023)]

# %%
keep_cols = [
    "ANNEE", "TRIM", "periode",
    "METRODOM",
    "NATIO",
    "SEXE",
    "AGE3", "AGE5",
    "PCSL", "PCSP", "STAT_CS", "STAT_CSPRL",
    "SO"
]

keep_cols = [c for c in keep_cols if c in df_insee.columns]
df_insee = df_insee[keep_cols]
df_insee.head()
# Out:
#    ANNEE  TRIM    periode  METRODOM  NATIO  SEXE  AGE3  AGE5 PCSL PCSP  \
# 0   2020     4 2020-10-01         1    NaN     2  50.0  60.0  NaN  NaN
# 1   2020     1 2020-01-01         1    NaN     1  50.0  60.0  NaN  NaN
# 2   2020     1 2020-01-01         1    NaN     2  50.0  60.0  NaN  NaN
# 3   2020     2 2020-04-01         1    NaN     1  50.0  60.0  NaN  NaN
# 4   2020     2 2020-04-01         1    NaN     2  50.0  60.0  NaN  NaN
#
#    STAT_CS  STAT_CSPRL  SO
# 0      NaN         NaN NaN
# 1      NaN         NaN NaN
# 2      NaN         NaN NaN
# 3      NaN         NaN NaN
# 4      NaN         NaN NaN

# %%
df_insee.shape
# Out:
# (1360290, 13)

# %%
df_insee.isna().mean().sort_values(ascending=False).head(10)
# Out:
# PCSP          0.779976
# AGE3          0.765199
# AGE5          0.765199
# STAT_CSPRL    0.748908
# PCSL          0.748907
# STAT_CS       0.748313
# NATIO         0.743713
# SO            0.743713
# ANNEE         0.000000
# TRIM          0.000000
# dtype: float64

# %%
df_insee.duplicated().sum()
# Out:
# np.int64(1181066)

# %%
[c for c in df_raw_insee.columns if "SEXE" in c]
# Out:
# ['SEXE']

# %%
df_insee[["ANNEE","TRIM"]].drop_duplicates().sort_values(["ANNEE","TRIM"]).head(20)
# Out:
#         ANNEE  TRIM
# 1        2020     1
# 3        2020     2
# 5        2020     3
# 0        2020     4
# 0        2021     1
# 86384    2021     2
# 172268   2021     3
# 256830   2021     4
# 0        2022     1
# 88589    2022     2
# 176440   2022     3
# 262536   2022     4
# 0        2023     1
# 88226    2023     2
# 175816   2023     3
# 261647   2023     4

# %%
df_raw_varmod20 = pd.read_csv("../data/raw/insee/varmod/Varmod_EEC_2020.csv", sep=";")
df_raw_varmod21 = pd.read_csv("../data/raw/insee/varmod/Varmod_EEC_2021.csv", sep=";")
df_raw_varmod22 = pd.read_csv("../data/raw/insee/varmod/Varmod_EEC_2022.csv", sep=";")
df_raw_varmod23 = pd.read_csv("../data/raw/insee/varmod/Varmod_EEC_2023.csv", sep=";")

# %%
df_raw_varmod = pd.concat([df_raw_varmod20, df_raw_varmod21, df_raw_varmod22, df_raw_varmod23])

# %%
df_varmod = df_raw_varmod.copy()

# %%
df_varmod.head(3)
# Out:
#   COD_VAR                              LIB_VAR COD_MOD  \
# 0   ANNEE      Année de référence de l'enquête    2020
# 1    TRIM  Trimestre de référence de l'enquête       1
# 2    TRIM  Trimestre de référence de l'enquête       2
#
#                               LIB_MOD TYPE_VAR  LONG_VAR
# 0  Année de référence sur 4 positions     CHAR       4.0
# 1            1er trimestre de l'année     CHAR       1.0
# 2             2e trimestre de l'année     CHAR       1.0

# %%
keywords = [
    "ancienneté", "emploi", "chômage", "chomage", "activité", "actif", "statut", "profession", "categorie", "catégorie", "pcs", "sexe", "âge", "age"
]
mask = df_varmod["LIB_VAR"].str.lower().str.contains("|".join(keywords), na=False)
vars_interessantes = df_varmod.loc[mask, ["COD_VAR", "LIB_VAR"]].drop_duplicates()

vars_interessantes.sort_values("COD_VAR").head(30)
# Out:
#         COD_VAR                                            LIB_VAR
# 766         AAC  Exercice d'une activité professionnelle réguli...
# 4    ACL_EMPLOI  Classe d'emploi (emploi actuel ou dernier emploi)
# 4         ACTEU  Statut d'activité au sens du Bureau Internatio...
# 38        ACTEU  Statut d'activité au sens du Bureau Internatio...
# 42       ACTEU6  Statut d'activité au sens du Bureau Internatio...
# 48        ACTIF                               Actif au sens du BIT
# 51        ACTOP  Actif occupé au sens du Bureau International d...
# 18         AGE3  Âge au dernier jour de la semaine de référence...
# 22         AGE5  Âge au dernier jour de la semaine de référence...
# 35       AISCO2               Code ISCO (dernier emploi, niveau 2)
# 57      ANCCHOM                  Ancienneté de chômage en 8 postes
# 13      ANCCHOM                              Ancienneté au chômage
# 23     ANCEMPL4        Ancienneté en 4 tranches (emploi principal)
# 754    ANCENTR4  Ancienneté dans l'entreprise ou dans la foncti...
# 66     ANCINACT  Ancienneté de l'inactivité ou du chômage en 8 ...
# 29     ANCSSEMP                             Ancienneté sans emploi
# 118       APCS1  Catégorie socio-professionnelle (PCS) du derni...
# 126       APCS2  Catégorie socio-professionnelle (PCS) du derni...
# 5    CATAU2010R  Catégorie regroupée de commune du logement de ...
# 282       CHPUB  Nature de l'employeur de la profession principale
# 41        CHPUB           Nature de l'employeur (emploi principal)
# 50    CL_EMPLOI                 Classe d'emploi (emploi principal)
# 75      CONTACT  Existence d'un contact avec Pôle Emploi ou un ...
# 28       COURED  Individu en couple dans le ménage au trimestre...
# 78      CREACCP  Raison principale de la recherche d'un autre e...
# 769         CSA  Catégorie socioprofessionnelle (2 chiffres) du...
# 290         CSE  Catégorie socioprofessionnelle (2 chiffres) po...
# 325        CSER  Catégorie socioprofessionnelle (1 chiffre) pou...
# 334         CSP  Catégorie socioprofessionnelle (2 chiffres) po...
# 368       CSTOT  Catégorie socioprofessionnelle (2 chiffres), n...

# %%
candidates = vars_interessantes["COD_VAR"].unique().tolist()
existing = [c for c in candidates if c in df_insee.columns]

len(candidates), len(existing)
# Out:
# (139, 8)

# %%
vars_existantes = vars_interessantes[vars_interessantes["COD_VAR"].isin(existing)]
vars_existantes.head(40)
# Out:
#          COD_VAR                                            LIB_VAR
# 18          AGE3  Âge au dernier jour de la semaine de référence...
# 22          AGE5  Âge au dernier jour de la semaine de référence...
# 36          SEXE                                               Sexe
# 1169        PCSL  PCS Logement calculée à partir du statut au se...
# 1187        PCSP                             PCS Ménage des parents
# 1295          SO     Statut d'occupation du ménage dans le logement
# 1333     STAT_CS  Statut (au sens spontané) selon la catégorie s...
# 1442  STAT_CSPRL  Statut (au sens spontané) selon la catégorie s...

# %%
selected_vars = [
    "ANNEE", "TRIM", "periode",
    "AGE5", "SEXE",
    "STAT_CS", "STAT_CSPRL",
    "PCSL", "PCSP"
]

selected_vars = [c for c in selected_vars if c in df_insee.columns]

df_insee_clean = df_insee[selected_vars].copy()
df_insee_clean.shape, df_insee_clean.columns
# Out:
# ((1360290, 9),
#  Index(['ANNEE', 'TRIM', 'periode', 'AGE5', 'SEXE', 'STAT_CS', 'STAT_CSPRL',
#         'PCSL', 'PCSP'],
#        dtype='object'))

# %%
df_insee_clean
# Out:
#         ANNEE  TRIM    periode  AGE5  SEXE  STAT_CS  STAT_CSPRL  PCSL   PCSP
# 0        2020     4 2020-10-01  60.0     2      NaN         NaN   NaN    NaN
# 1        2020     1 2020-01-01  60.0     1      NaN         NaN   NaN    NaN
# 2        2020     1 2020-01-01  60.0     2      NaN         NaN   NaN    NaN
# 3        2020     2 2020-04-01  60.0     1      NaN         NaN   NaN    NaN
# 4        2020     2 2020-04-01  60.0     2      NaN         NaN   NaN    NaN
# ...       ...   ...        ...   ...   ...      ...         ...   ...    ...
# 348619   2023     4 2023-10-01   NaN     1    365.0       365.0  VI-B    NaN
# 348620   2023     4 2023-10-01   NaN     2    352.0       352.0  VI-A  VII-A
# 348621   2023     4 2023-10-01   NaN     2    356.0       356.0   V-A  VII-A
# 348622   2023     4 2023-10-01   NaN     1    367.0       356.0   V-A   VI-B
# 348623   2023     4 2023-10-01   NaN     1    147.0       356.0   V-A    V-A
#
# [1360290 rows x 9 columns]

# %%
df_varmod[df_varmod["COD_VAR"].isin(["STAT_CS","STAT_CSPRL","AGE5","SEXE","PCSL","PCSP"])][
    ["COD_VAR","COD_MOD","LIB_MOD"]
].drop_duplicates().sort_values(["COD_VAR","COD_MOD"]).head(60)
# Out:
#       COD_VAR COD_MOD                                            LIB_MOD
# 22       AGE5       0                                      De 0 à 14 ans
# 23       AGE5      15                                     De 15 à 29 ans
# 24       AGE5      30                                     De 30 à 39 ans
# 25       AGE5      40                                     De 40 à 49 ans
# 26       AGE5      50                                     De 50 à 59 ans
# 27       AGE5      60                                     60 ans ou plus
# 1185     PCSL     999                                          Non codés
# 1169     PCSL     I-A                                   Cadre avec cadre
# 1170     PCSL     I-B                Cadre avec profession intermédiaire
# 1171     PCSL    II-A                      Cadre avec employé ou ouvrier
# 1172     PCSL    II-B                Cadre avec inactif ou sans conjoint
# 1173     PCSL    II-C  Profession intermédiaire ou cadre avec petit i...
# 1174     PCSL    II-D  Profession intermédiaire avec profession inter...
# 1175     PCSL   III-A   Profession intermédiaire avec employé ou ouvrier
# 1176     PCSL   III-B  Profession intermédiaire avec inactif ou sans ...
# 1177     PCSL   III-C                               Employé avec employé
# 1178     PCSL    IV-A  Petit indépendant avec petit indépendant, avec...
# 1179     PCSL    IV-B          Petit indépendant avec employé ou ouvrier
# 1180     PCSL     V-A                              Ouvrier avec employél
# 1181     PCSL     V-B                               Ouvrier avec ouvrier
# 1182     PCSL    VI-A              Employé avec inactif ou sans conjoint
# 1183     PCSL    VI-B              Ouvrier avec inactif ou sans conjoint
# 1184     PCSL   VII-A              Inactif avec inactif ou sans conjoint
# 1186     PCSL     NaN                                         Hors champ
# 1203     PCSP     999                                          Non codés
# 1187     PCSP     I-A                                   Cadre avec cadre
# 1188     PCSP     I-B                Cadre avec profession intermédiaire
# 1189     PCSP    II-A                      Cadre avec employé ou ouvrier
# 1190     PCSP    II-B                Cadre avec inactif ou sans conjoint
# 1191     PCSP    II-C  Profession intermédiaire ou cadre avec petit i...
# 1192     PCSP    II-D  Profession intermédiaire avec profession inter...
# 1193     PCSP   III-A   Profession intermédiaire avec employé ou ouvrier
# 1194     PCSP   III-B  Profession intermédiaire avec inactif ou sans ...
# 1195     PCSP   III-C                               Employé avec employé
# 1196     PCSP    IV-A  Petit indépendant avec petit indépendant, avec...
# 1197     PCSP    IV-B          Petit indépendant avec employé ou ouvrier
# 1198     PCSP     V-A                              Ouvrier avec employél
# 1199     PCSP     V-B                               Ouvrier avec ouvrier
# 1200     PCSP    VI-A              Employé avec inactif ou sans conjoint
# 1201     PCSP    VI-B              Ouvrier avec inactif ou sans conjoint
# 1202     PCSP   VII-A              Inactif avec inactif ou sans conjoint
# 1204     PCSP     NaN                                         Hors champ
# 36       SEXE       1                                           Masculin
# 1133     SEXE       1                                              Homme
# 37       SEXE       2                                            Féminin
# 1134     SEXE       2                                              Femme
# 1333  STAT_CS     110  Personnes en emploi : Exploitants agricoles, f...
# 1334  STAT_CS     120  Personnes en emploi : Artisans, commerçants et...
# 1335  STAT_CS     121                     Personnes en emploi : Artisans
# 1336  STAT_CS     122     Personnes en emploi : Commerçants et assimilés
# 1337  STAT_CS     123  Personnes en emploi : Chefs d'entreprise de pl...
# 1338  STAT_CS     130  Personnes en emploi : Cadres et professions in...
# 1339  STAT_CS     131        Personnes en emploi : Professions libérales
# 1340  STAT_CS     133  Personnes en emploi : Cadres de la fonction pu...
# 1341  STAT_CS     134  Personnes en emploi : Professeurs et professio...
# 1342  STAT_CS     135  Personnes en emploi : Professions de l’informa...
# 1343  STAT_CS     137  Personnes en emploi : Cadres des services admi...
# 1344  STAT_CS     138  Personnes en emploi : Ingénieurs et cadres tec...
# 1345  STAT_CS     140   Personnes en emploi : Professions intermédiaires
# 1346  STAT_CS     142  Personnes en emploi : Professions de l’enseign...

# %%
df_insee_clean.shape
# Out:
# (1360290, 9)

# %%
final_vars = [
    "ANNEE", "TRIM", "periode",
    "AGE5", "SEXE",
    "STAT_CS", "STAT_CSPRL"
]

df_insee_clean = df_insee[final_vars].copy()
df_insee_clean.shape, df_insee_clean.columns
# Out:
# ((1360290, 7),
#  Index(['ANNEE', 'TRIM', 'periode', 'AGE5', 'SEXE', 'STAT_CS', 'STAT_CSPRL'], dtype='object'))

# %%
from pathlib import Path
Path("../data/processed").mkdir(parents=True, exist_ok=True)

df_insee_clean.to_parquet(
    "../data/processed/insee_eec_clean.parquet",
    index=False
)

# %% [markdown]
# 3. Standardisation des colonnes

# %% [markdown]
# 4. Gestion des dates

# %% [markdown]
# 5. Filtrage du périmètre

# %% [markdown]
# 6. Table finale
